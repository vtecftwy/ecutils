# %% [raw]
# ---
# description: Set of utility function to be used in Jupyter Notebook and Jupyter Lab
#   notebooks
# output-file: ipython.html
# title: '`ipython` module - Utility functions for Jupyter NB'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(display_mds)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/ecutils/tree/master/blob/master/ecutils/ipython.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### display_mds
#
# >      display_mds (*strings)
#
# Utility function to display several strings formatted in markdown format
#
# :param strings: any number of strings with text in markdown format
# :return: None

# %%
#|output: asis
#| echo: false
show_doc(display_dfs)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/ecutils/tree/master/blob/master/ecutils/ipython.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### display_dfs
#
# >      display_dfs (*dfs)
#
# Utility function to display several DataFrame with one operations
# :param dfs: any number of Pandas DataFrames
# :return: None

# %%
#|output: asis
#| echo: false
show_doc(nb_setup)
# Out:
# ---
#
# [source](https://github.com/vtecftwy/ecutils/tree/master/blob/master/ecutils/ipython.py#L36){target="_blank" style="float:right; font-size:smaller"}
#
# ### nb_setup
#
# >      nb_setup (autoreload=True, paths=None)
#
# Use in first cell of nb for setting up autoreload, paths, ...
#
# By default, nb_setup() loads and set autoreload and adds a path to a directory named 'src'
# at the same level as where the notebook directory is located.
#
# By default, nb_setup assumes the following file structure:
#
# project_directory
#       | --- notebooks
#       |        | --- current_nb.ipynb
#       |        | --- ...
#       |
#       |--- src
#       |     | --- scripts_to_import.py
#       |     | --- ...
#       |
#       |--- data
#       |     |
#       |     | ...
